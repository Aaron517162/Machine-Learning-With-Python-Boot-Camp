# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaron517162/Machine-Learning-With-Python-Boot-Camp/blob/main/Orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime

birth_year = int(input("Enter your birth year: ").index())
current_year = datetime.datetime.now().year
age = current_year - birth_year
print(f"Your age is: {age}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3540/4201269174.py in <cell line: 0>()
#       1 import datetime
#       2
# ----> 3 birth_year = int(input("Enter your birth year: ").index())
#       4 current_year = datetime.datetime.now().year
#       5 age = current_year - birth_year
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# Example of Addition

# %%
A=2
B=3
C=A+B
print(C)
# Out:
# 5

# %%
Example of a string

# %% [markdown]
# Example of a String

# %%
Greeting= "what up doctor"
print (Greeting)
# Out:
# what up doctor

# %%
Greeting= " Hello World"
print (Greeting)
# Out:
#  Hello World

# %%
from IPython.core.display import Image
import numpy as np
import IPython.display as display
from matplotlib import pyplot as pyplot
import io
import base64
ys = 200 + np.random.random(100)
x = [x for x in range (len(ys))]

fig = plt.figure (figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill-between (x,ys,195,where=(ys> 195), facecolor= 'b', alpha=0.6)
plt.title("sample visualization", fontsize=10)
data = io.BytesIO()
plt .savefig(data)
Image = F"data :image/png;base64,{base64.b64encode(data.getvalue()) .decode()}"
alt = "sample Visuallization"
display .display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4362/383844104.py in <cell line: 0>()
#       8 x = [x for x in range (len(ys))]
#       9
# ---> 10 fig = plt.figure (figsize=(4, 3), facecolor='w')
#      11 plt.plot(x, ys, '-')
#      12 plt.fill-between (x,ys,195,where=(ys> 195), facecolor= 'g', alpha=0.6)
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(6, 7), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.8)
plt.title("Sample Visualization", fontsize=8)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %%
worksheet =gc.open ('my cool spredsheet')
