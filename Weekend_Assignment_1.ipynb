# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaron517162/Machine-Learning-With-Python-Boot-Camp/blob/main/Weekend_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1

# %%
Liberia = 1847
print (Liberia)
print ("Liberia")
# Out:
# 1847
# Liberia

# %% [markdown]
# **Problem 2**

# %%
country = "Liberia"  # Store the country name in a variable
year = 1847  # Store the year in a variable
print(country, "became independent in", year) # Use to print multiple items
# Out:
# Liberia became independent in 1847

# %% [markdown]
# **Problem 3**

# %%
print ('The year of ',country,'was "1847"')
# Out:
# The year of  Liberia was "1847"

# %% [markdown]
# **Problem 4**

# %%
market_name = "Gobachop Market"
total_market_table = 150
price_per_beg = 3200.50
is_market_open =True
print (type (market_name))
print (type (total_market_table))
print (type (price_per_beg))
print (type (is_market_open))

# print the type of each variable
print("type of market_name:", type(market_name))
print("type of total_market_table:", type(total_market_table))
print ("type of price_per_beg:", type(price_per_beg))
print ("type of is_market_open:", type(is_market_open))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# type of market_name: <class 'str'>
# type of total_market_table: <class 'int'>
# type of price_per_beg: <class 'float'>
# type of is_market_open: <class 'bool'>

# %% [markdown]
# **Problem 5**

# %%
current_price = 2550.75
quantity = 10
total_cost = current_price * quantity
print("total cost for 10 bags:",total_cost,"LRD")
# Out:
# total cost for 10 bags: 25507.5 LRD

# %% [markdown]
# **Problem 6**

# %%
has_scarcity = False
is_rainy = True
print("Scarcity today:", has_scarcity)
print("Rainy today:", is_rainy)
# Out:
# Scarcity today: False
# Rainy today: True

# %% [markdown]
# **Problem 7**

# %%
price_per_bag
quantity = 25
total_revenue = price_per_bag * quantity
print("Total_revenue for 25 bags:",total_revenue,"USD")
# Out:
# Total_revenue for 25 bags: 20000 USD

# %% [markdown]
# **Problem 8**

# %%
today_price = 3200
increase = 150
tomorrow_price = today_price + increase  # Add increase to today`s price

print("Tomorrow`s rice price:", tomorrow_price, "LRD")
# Out:
# Tomorrow`s rice price: 3350 LRD

# %% [markdown]
# **Problem 9**

# %%
cost_per_traders = 1800
trader = 3
cost_per_trader = cost_per_traders / trader
print('cost_per_trader:',cost_per_trader,"LRD")
# Out:
# cost_per_trader: 600.0 LRD

# %% [markdown]
# **Problem 10**

# %%
original_price = 2500
discount_rate = 0.10

discount_amount = original_price * discount_rate
final_price = original_price - discount_amount

print("Discount amount:", discount_amount, "LRD")
print("Final price after discount:", final_price, "LRD")
# Out:
# Discount amount: 250.0 LRD
# Final price after discount: 2250.0 LRD

# %% [markdown]
# **Problem 11**

# %%
item = "cassava"
price = 800
print(item)
print("item")
print(price)
print("price")
# Out:
# cassava
# item
# 800
# price

# %% [markdown]
# **Problem 12**

# %%
product = "pepper"
cost = 150.50
print("One bag of", product, "costs", cost, "LRD")
# Out:
# One bag of pepper costs 150.5 LRD
